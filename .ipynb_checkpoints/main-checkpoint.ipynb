# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# import reduce from functools, numpy and pandas
import numpy as np
import pandas as pd
from functools import reduce

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up a words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')
len(prophet)
# Out:
# 13637

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# Your code here:
def half(x):
    return x/2

l = [10, 12, 18]
l2= list(map(half, l))  #casts it to a list, you can also do it to a set(sets have unique values) 

print(l2)

# %%
prophet2 = prophet[567:]
prophet2
# Out:
# ['Farewell................92\n\n\n\n\nTHE',
#  'PROPHET\n\n|Almustafa,',
#  'the{7}',
#  'chosen',
#  'and',
#  'the\nbeloved,',
#  'who',
#  'was',
#  'a',
#  'dawn',
#  'unto',
#  'his',
#  'own\nday,',
#  'had',
#  'waited',
#  'twelve',
#  'years',
#  'in',
#  'the',
#  'city\nof',
#  'Orphalese',
#  'for',
#  'his',
#  'ship',
#  'that',
#  'was',
#  'to\nreturn',
#  'and',
#  'bear',
#  'him',
#  'back',
#  'to',
#  'the',
#  'isle',
#  'of\nhis',
#  'birth.\n\nAnd',
#  'in',
#  'the',
#  'twelfth',
#  'year,',
#  'on',
#  'the',
#  'seventh\nday',
#  'of',
#  'Ielool,',
#  'the',
#  'month',
#  'of',
#  'reaping,',
#  'he\nclimbed',
#  'the',
#  'hill',
#  'without',
#  'the',
#  'city',
#  'walls\nand',
#  'looked',
#  'seaward;',
#  'and',
#  'he',
#  'beheld',
#  'his\nship',
#  'coming',
#  'with',
#  'the',
#  'mist.\n\nThen',
#  'the',
#  'gates',
#  'of',
#  'his',
#  'heart',
#  'were',
#  'flung\nopen,',
#  'and',
#  'his',
#  'joy',
#  'flew',
#  'far',
#  'over',
#  'the',
#  'sea.\nAnd',
#  'he',
#  'closed',
#  'his',
#  'eyes',
#  'and',
#  'prayed',
#  'in',
#  'the\nsilences',
#  'of',
#  'his',
#  'soul.\n\n*****\n\nBut',
#  'as',
#  'he',
#  'descended',
#  'the',
#  'hill,',
#  'a',
#  'sadness\ncame',
#  'upon',
#  'him,',
#  'and',
#  'he',
#  'thought',
#  'in',
#  'his\nheart:\n\nHow',
#  'shall',
#  'I',
#  'go',
#  'in',
#  'peace',
#  'and',
#  'without\nsorrow?',
#  'Nay,',
#  'not',
#  'without',
#  'a',
#  'wound',
#  'in',
#  'the\nspirit',
#  'shall',
#  'I',
#  'leave',
#  'this',
#  'city.',
#  '{8}Long\nwere',
#  'the',
#  'days',
#  'of',
#  'pain',
#  'I',
#  'have',
#  'spent\nwithin',
#  'its',
#  'walls,',
#  'and',
#  'long',
#  'were',
#  'the\nnights',
#  'of',
#  'aloneness;',
#  'and',
#  'who',
#  'can',
#  'depart\nfrom',
#  'his',
#  'pain',
#  'and',
#  'his',
#  'aloneness',
#  'without\nregret?\n\nToo',
#  'many',
#  'fragments',
#  'of',
#  'the',
#  'spirit',
#  'have',
#  'I\nscattered',
#  'in',
#  'these',
#  'streets,',
#  'and',
#  'too',
#  'many\nare',
#  'the',
#  'children',
#  'of',
#  'my',
#  'longing',
#  'that',
#  'walk\nnaked',
#  'among',
#  'these',
#  'hills,',
#  'and',
#  'I',
#  'cannot\nwithdraw',
#  'from',
#  'them',
#  'without',
#  'a',
#  'burden',
#  'and\nan',
#  'ache.\n\nIt',
#  'is',
#  'not',
#  'a',
#  'garment',
#  'I',
#  'cast',
#  'off',
#  'this\nday,',
#  'but',
#  'a',
#  'skin',
#  'that',
#  'I',
#  'tear',
#  'with',
#  'my',
#  'own\nhands.\n\nNor',
#  'is',
#  'it',
#  'a',
#  'thought',
#  'I',
#  'leave',
#  'behind',
#  'me,\nbut',
#  'a',
#  'heart',
#  'made',
#  'sweet',
#  'with',
#  'hunger',
#  'and\nwith',
#  'thirst.\n\n*****\n\nYet',
#  'I',
#  'cannot',
#  'tarry',
#  'longer.\n\nThe',
#  'sea',
#  'that',
#  'calls',
#  'all',
#  'things',
#  'unto',
#  'her\ncalls',
#  'me,',
#  'and',
#  'I',
#  'must',
#  'embark.\n\nFor',
#  'to',
#  'stay,',
#  'though',
#  'the',
#  'hours',
#  'burn',
#  'in\nthe',
#  'night,',
#  'is',
#  'to',
#  'freeze',
#  'and',
#  'crystallize\nand',
#  'be',
#  'bound',
#  'in',
#  'a',
#  'mould.\n\nFain',
#  'would',
#  'I',
#  'take',
#  'with',
#  'me',
#  'all',
#  'that',
#  'is\nhere.',
#  'But',
#  'how',
#  'shall',
#  'I?\n\nA',
#  'voice',
#  'cannot',
#  'carry',
#  'the',
#  'tongue',
#  'and\n{9}the',
#  'lips',
#  'that',
#  'gave',
#  'it',
#  'wings.',
#  'Alone\nmust',
#  'it',
#  'seek',
#  'the',
#  'ether.\n\nAnd',
#  'alone',
#  'and',
#  'without',
#  'his',
#  'nest',
#  'shall',
#  'the\neagle',
#  'fly',
#  'across',
#  'the',
#  'sun.\n\n*****\n\nNow',
#  'when',
#  'he',
#  'reached',
#  'the',
#  'foot',
#  'of',
#  'the\nhill,',
#  'he',
#  'turned',
#  'again',
#  'towards',
#  'the',
#  'sea,\nand',
#  'he',
#  'saw',
#  'his',
#  'ship',
#  'approaching',
#  'the\nharbour,',
#  'and',
#  'upon',
#  'her',
#  'prow',
#  'the',
#  'mariners,\nthe',
#  'men',
#  'of',
#  'his',
#  'own',
#  'land.\n\nAnd',
#  'his',
#  'soul',
#  'cried',
#  'out',
#  'to',
#  'them,',
#  'and',
#  'he\nsaid:\n\nSons',
#  'of',
#  'my',
#  'ancient',
#  'mother,',
#  'you',
#  'riders',
#  'of\nthe',
#  'tides,\n\nHow',
#  'often',
#  'have',
#  'you',
#  'sailed',
#  'in',
#  'my',
#  'dreams.\nAnd',
#  'now',
#  'you',
#  'come',
#  'in',
#  'my',
#  'awakening,',
#  'which\nis',
#  'my',
#  'deeper',
#  'dream.\n\nReady',
#  'am',
#  'I',
#  'to',
#  'go,',
#  'and',
#  'my',
#  'eagerness',
#  'with\nsails',
#  'full',
#  'set',
#  'awaits',
#  'the',
#  'wind.\n\nOnly',
#  'another',
#  'breath',
#  'will',
#  'I',
#  'breathe',
#  'in\nthis',
#  'still',
#  'air,',
#  'only',
#  'another',
#  'loving',
#  'look\ncast',
#  'backward,\n\nAnd',
#  'then',
#  'I',
#  'shall',
#  'stand',
#  'among',
#  'you,',
#  'a\nseafarer',
#  'among',
#  'seafarers.',
#  '{10}And',
#  'you,\nvast',
#  'sea,',
#  'sleepless',
#  'mother,\n\nWho',
#  'alone',
#  'are',
#  'peace',
#  'and',
#  'freedom',
#  'to',
#  'the\nriver',
#  'and',
#  'the',
#  'stream,\n\nOnly',
#  'another',
#  'winding',
#  'will',
#  'this',
#  'stream\nmake,',
#  'only',
#  'another',
#  'murmur',
#  'in',
#  'this',
#  'glade,\n\nAnd',
#  'then',
#  'shall',
#  'I',
#  'come',
#  'to',
#  'you,',
#  'a\nboundless',
#  'drop',
#  'to',
#  'a',
#  'boundless',
#  'ocean.\n\n*****\n\nAnd',
#  'as',
#  'he',
#  'walked',
#  'he',
#  'saw',
#  'from',
#  'afar',
#  'men\nand',
#  'women',
#  'leaving',
#  'their',
#  'fields',
#  'and',
#  'their\nvineyards',
#  'and',
#  'hastening',
#  'towards',
#  'the',
#  'city\ngates.\n\nAnd',
#  'he',
#  'heard',
#  'their',
#  'voices',
#  'calling',
#  'his\nname,',
#  'and',
#  'shouting',
#  'from',
#  'field',
#  'to',
#  'field\ntelling',
#  'one',
#  'another',
#  'of',
#  'the',
#  'coming',
#  'of',
#  'his\nship.\n\nAnd',
#  'he',
#  'said',
#  'to',
#  'himself:\n\nShall',
#  'the',
#  'day',
#  'of',
#  'parting',
#  'be',
#  'the',
#  'day',
#  'of\ngathering?\n\nAnd',
#  'shall',
#  'it',
#  'be',
#  'said',
#  'that',
#  'my',
#  'eve',
#  'was',
#  'in\ntruth',
#  'my',
#  'dawn?\n\nAnd',
#  'what',
#  'shall',
#  'I',
#  'give',
#  'unto',
#  'him',
#  'who',
#  'has\nleft',
#  'his',
#  'plough',
#  'in',
#  'midfurrow,',
#  'or',
#  'to\nhim',
#  'who',
#  'has',
#  'stopped',
#  'the',
#  'wheel',
#  'of',
#  'his\nwinepress?',
#  '{11}Shall',
#  'my',
#  'heart',
#  'become',
#  'a\ntree',
#  'heavy-laden',
#  'with',
#  'fruit',
#  'that',
#  'I',
#  'may\ngather',
#  'and',
#  'give',
#  'unto',
#  'them?\n\nAnd',
#  'shall',
#  'my',
#  'desires',
#  'flow',
#  'like',
#  'a\nfountain',
#  'that',
#  'I',
#  'may',
#  'fill',
#  'their',
#  'cups?\n\nAm',
#  'I',
#  'a',
#  'harp',
#  'that',
#  'the',
#  'hand',
#  'of',
#  'the',
#  'mighty\nmay',
#  'touch',
#  'me,',
#  'or',
#  'a',
#  'flute',
#  'that',
#  'his',
#  'breath\nmay',
#  'pass',
#  'through',
#  'me?\n\nA',
#  'seeker',
#  'of',
#  'silences',
#  'am',
#  'I,',
#  'and',
#  'what\ntreasure',
#  'have',
#  'I',
#  'found',
#  'in',
#  'silences',
#  'that',
#  'I\nmay',
#  'dispense',
#  'with',
#  'confidence?\n\nIf',
#  'this',
#  'is',
#  'my',
#  'day',
#  'of',
#  'harvest,',
#  'in',
#  'what\nfields',
#  'have',
#  'I',
#  'sowed',
#  'the',
#  'seed,',
#  'and',
#  'in\nwhat',
#  'unremembered',
#  'seasons?\n\nIf',
#  'this',
#  'indeed',
#  'be',
#  'the',
#  'hour',
#  'in',
#  'which',
#  'I\nlift',
#  'up',
#  'my',
#  'lantern,',
#  'it',
#  'is',
#  'not',
#  'my',
#  'flame\nthat',
#  'shall',
#  'burn',
#  'therein.\n\nEmpty',
#  'and',
#  'dark',
#  'shall',
#  'I',
#  'raise',
#  'my',
#  'lantern,\n\nAnd',
#  'the',
#  'guardian',
#  'of',
#  'the',
#  'night',
#  'shall',
#  'fill\nit',
#  'with',
#  'oil',
#  'and',
#  'he',
#  'shall',
#  'light',
#  'it',
#  'also.\n\n*****\n\nThese',
#  'things',
#  'he',
#  'said',
#  'in',
#  'words.',
#  'But',
#  'much\nin',
#  'his',
#  'heart',
#  'remained',
#  'unsaid.',
#  'For',
#  '{12}he\nhimself',
#  'could',
#  'not',
#  'speak',
#  'his',
#  'deeper\nsecret.\n\n*****\n\n[Illustration:',
#  '0020]\n\nAnd',
#  'when',
#  'he',
#  'entered',
#  'into',
#  'the',
#  'city',
#  'all\nthe',
#  'people',
#  'came',
#  'to',
#  'meet',
#  'him,',
#  'and',
#  'they\nwere',
#  'crying',
#  'out',
#  'to',
#  'him',
#  'as',
#  'with',
#  'one\nvoice.\n\nAnd',
#  'the',
#  'elders',
#  'of',
#  'the',
#  'city',
#  'stood',
#  'forth\nand',
#  'said:\n\nGo',
#  'not',
#  'yet',
#  'away',
#  'from',
#  'us.\n\nA',
#  'noontide',
#  'have',
#  'you',
#  'been',
#  'in',
#  'our\ntwilight,',
#  'and',
#  'your',
#  'youth',
#  'has',
#  'given',
#  'us\ndreams',
#  'to',
#  'dream.\n\nNo',
#  'stranger',
#  'are',
#  'you',
#  'among',
#  'us,',
#  'nor\na',
#  'guest,',
#  'but',
#  'our',
#  'son',
#  'and',
#  'our',
#  'dearly\nbeloved.\n\nSuffer',
#  'not',
#  'yet',
#  'our',
#  'eyes',
#  'to',
#  'hunger',
#  'for\nyour',
#  'face.\n\n*****\n\nAnd',
#  'the',
#  'priests',
#  'and',
#  'the',
#  'priestesses',
#  'said\nunto',
#  'him:\n\nLet',
#  'not',
#  'the',
#  'waves',
#  'of',
#  'the',
#  'sea',
#  'separate',
#  'us\nnow,',
#  'and',
#  'the',
#  'years',
#  'you',
#  'have',
#  'spent',
#  'in',
#  'our\nmidst',
#  'become',
#  'a',
#  'memory.\n\nYou',
#  'have',
#  'walked',
#  'among',
#  'us',
#  'a',
#  'spirit,\n{13}and',
#  'your',
#  'shadow',
#  'has',
#  'been',
#  'a',
#  'light\nupon',
#  'our',
#  'faces.\n\nMuch',
#  'have',
#  'we',
#  'loved',
#  'you.',
#  'But',
#  'speechless\nwas',
#  'our',
#  'love,',
#  'and',
#  'with',
#  'veils',
#  'has',
#  'it',
#  'been\nveiled.\n\nYet',
#  'now',
#  'it',
#  'cries',
#  'aloud',
#  'unto',
#  'you,',
#  'and\nwould',
#  'stand',
#  'revealed',
#  'before',
#  'you.\n\nAnd',
#  'ever',
#  'has',
#  'it',
#  'been',
#  'that',
#  'love',
#  'knows\nnot',
#  'its',
#  'own',
#  'depth',
#  'until',
#  'the',
#  'hour',
#  'of\nseparation.\n\n*****\n\nAnd',
#  'others',
#  'came',
#  'also',
#  'and',
#  'entreated',
#  'him.\nBut',
#  'he',
#  'answered',
#  'them',
#  'not.',
#  'He',
#  'only',
#  'bent\nhis',
#  'head;',
#  'and',
#  'those',
#  'who',
#  'stood',
#  'near',
#  'saw\nhis',
#  'tears',
#  'falling',
#  'upon',
#  'his',
#  'breast.\n\nAnd',
#  'he',
#  'and',
#  'the',
#  'people',
#  'proceeded',
#  'towards\nthe',
#  'great',
#  'square',
#  'before',
#  'the',
#  'temple.\n\nAnd',
#  'there',
#  'came',
#  'out',
#  'of',
#  'the',
#  'sanctuary',
#  'a\nwoman',
#  'whose',
#  'name',
#  'was',
#  'Almitra.',
#  'And',
#  'she\nwas',
#  'a',
#  'seeress.\n\nAnd',
#  'he',
#  'looked',
#  'upon',
#  'her',
#  'with',
#  'exceeding\ntenderness,',
#  'for',
#  'it',
#  'was',
#  'she',
#  'who',
#  'had',
#  'first\nsought',
#  'and',
#  'believed',
#  'in',
#  'him',
#  'when',
#  'he',
#  'had\nbeen',
#  'but',
#  'a',
#  'day',
#  'in',
#  'their',
#  'city.',
#  '{14}And\nshe',
#  'hailed',
#  'him,',
#  'saying:\n\nProphet',
#  'of',
#  'God,',
#  'in',
#  'quest',
#  'of',
#  'the\nuttermost,',
#  'long',
#  'have',
#  'you',
#  'searched',
#  'the\ndistances',
#  'for',
#  'your',
#  'ship.\n\nAnd',
#  'now',
#  'your',
#  'ship',
#  'has',
#  'come,',
#  'and',
#  'you',
#  'must\nneeds',
#  'go.\n\nDeep',
#  'is',
#  'your',
#  'longing',
#  'for',
#  'the',
#  'land',
#  'of\nyour',
#  'memories',
#  'and',
#  'the',
#  'dwelling',
#  'place\nof',
#  'your',
#  'greater',
#  'desires;',
#  'and',
#  'our',
#  'love\nwould',
#  'not',
#  'bind',
#  'you',
#  'nor',
#  'our',
#  'needs',
#  'hold\nyou.\n\nYet',
#  'this',
#  'we',
#  'ask',
#  'ere',
#  'you',
#  'leave',
#  'us,',
#  'that\nyou',
#  'speak',
#  'to',
#  'us',
#  'and',
#  'give',
#  'us',
#  'of',
#  'your\ntruth.\n\nAnd',
#  'we',
#  'will',
#  'give',
#  'it',
#  'unto',
#  'our',
#  'children,\nand',
#  'they',
#  'unto',
#  'their',
#  'children,',
#  'and',
#  'it\nshall',
#  'not',
#  'perish.\n\nIn',
#  'your',
#  'aloneness',
#  'you',
#  'have',
#  'watched',
#  'with\nour',
#  'days,',
#  'and',
#  'in',
#  'your',
#  'wakefulness',
#  'you\nhave',
#  'listened',
#  'to',
#  'the',
#  'weeping',
#  'and',
#  'the\nlaughter',
#  'of',
#  'our',
#  'sleep.\n\nNow',
#  'therefore',
#  'disclose',
#  'us',
#  'to',
#  'ourselves,\nand',
#  'tell',
#  'us',
#  'all',
#  'that',
#  'has',
#  'been',
#  'shown\nyou',
#  'of',
#  'that',
#  'which',
#  'is',
#  'between',
#  'birth',
#  'and\ndeath.\n\n*****\n\nAnd',
#  'he',
#  'answered,\n\nPeople',
#  'of',
#  ...]

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# Your code here:
prophet3 = prophet2[0:10]
prophet3
# Out:
# ['Farewell................92\n\n\n\n\nTHE',
#  'PROPHET\n\n|Almustafa,',
#  'the{7}',
#  'chosen',
#  'and',
#  'the\nbeloved,',
#  'who',
#  'was',
#  'a',
#  'dawn']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    return x.rsplit("{")[0]

    
    # Your code here:
# Out:
# ['Farewell................92\n\n\n\n\nTHE', 'PROPHET\n\n|Almustafa,', 'the', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn']

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`

# %%
# Your code here:
prophet_reference = list(map(reference, prophet2))
prophet_reference
# Out:
# ['Farewell................92\n\n\n\n\nTHE',
#  'PROPHET\n\n|Almustafa,',
#  'the',
#  'chosen',
#  'and',
#  'the\nbeloved,',
#  'who',
#  'was',
#  'a',
#  'dawn',
#  'unto',
#  'his',
#  'own\nday,',
#  'had',
#  'waited',
#  'twelve',
#  'years',
#  'in',
#  'the',
#  'city\nof',
#  'Orphalese',
#  'for',
#  'his',
#  'ship',
#  'that',
#  'was',
#  'to\nreturn',
#  'and',
#  'bear',
#  'him',
#  'back',
#  'to',
#  'the',
#  'isle',
#  'of\nhis',
#  'birth.\n\nAnd',
#  'in',
#  'the',
#  'twelfth',
#  'year,',
#  'on',
#  'the',
#  'seventh\nday',
#  'of',
#  'Ielool,',
#  'the',
#  'month',
#  'of',
#  'reaping,',
#  'he\nclimbed',
#  'the',
#  'hill',
#  'without',
#  'the',
#  'city',
#  'walls\nand',
#  'looked',
#  'seaward;',
#  'and',
#  'he',
#  'beheld',
#  'his\nship',
#  'coming',
#  'with',
#  'the',
#  'mist.\n\nThen',
#  'the',
#  'gates',
#  'of',
#  'his',
#  'heart',
#  'were',
#  'flung\nopen,',
#  'and',
#  'his',
#  'joy',
#  'flew',
#  'far',
#  'over',
#  'the',
#  'sea.\nAnd',
#  'he',
#  'closed',
#  'his',
#  'eyes',
#  'and',
#  'prayed',
#  'in',
#  'the\nsilences',
#  'of',
#  'his',
#  'soul.\n\n*****\n\nBut',
#  'as',
#  'he',
#  'descended',
#  'the',
#  'hill,',
#  'a',
#  'sadness\ncame',
#  'upon',
#  'him,',
#  'and',
#  'he',
#  'thought',
#  'in',
#  'his\nheart:\n\nHow',
#  'shall',
#  'I',
#  'go',
#  'in',
#  'peace',
#  'and',
#  'without\nsorrow?',
#  'Nay,',
#  'not',
#  'without',
#  'a',
#  'wound',
#  'in',
#  'the\nspirit',
#  'shall',
#  'I',
#  'leave',
#  'this',
#  'city.',
#  '',
#  'the',
#  'days',
#  'of',
#  'pain',
#  'I',
#  'have',
#  'spent\nwithin',
#  'its',
#  'walls,',
#  'and',
#  'long',
#  'were',
#  'the\nnights',
#  'of',
#  'aloneness;',
#  'and',
#  'who',
#  'can',
#  'depart\nfrom',
#  'his',
#  'pain',
#  'and',
#  'his',
#  'aloneness',
#  'without\nregret?\n\nToo',
#  'many',
#  'fragments',
#  'of',
#  'the',
#  'spirit',
#  'have',
#  'I\nscattered',
#  'in',
#  'these',
#  'streets,',
#  'and',
#  'too',
#  'many\nare',
#  'the',
#  'children',
#  'of',
#  'my',
#  'longing',
#  'that',
#  'walk\nnaked',
#  'among',
#  'these',
#  'hills,',
#  'and',
#  'I',
#  'cannot\nwithdraw',
#  'from',
#  'them',
#  'without',
#  'a',
#  'burden',
#  'and\nan',
#  'ache.\n\nIt',
#  'is',
#  'not',
#  'a',
#  'garment',
#  'I',
#  'cast',
#  'off',
#  'this\nday,',
#  'but',
#  'a',
#  'skin',
#  'that',
#  'I',
#  'tear',
#  'with',
#  'my',
#  'own\nhands.\n\nNor',
#  'is',
#  'it',
#  'a',
#  'thought',
#  'I',
#  'leave',
#  'behind',
#  'me,\nbut',
#  'a',
#  'heart',
#  'made',
#  'sweet',
#  'with',
#  'hunger',
#  'and\nwith',
#  'thirst.\n\n*****\n\nYet',
#  'I',
#  'cannot',
#  'tarry',
#  'longer.\n\nThe',
#  'sea',
#  'that',
#  'calls',
#  'all',
#  'things',
#  'unto',
#  'her\ncalls',
#  'me,',
#  'and',
#  'I',
#  'must',
#  'embark.\n\nFor',
#  'to',
#  'stay,',
#  'though',
#  'the',
#  'hours',
#  'burn',
#  'in\nthe',
#  'night,',
#  'is',
#  'to',
#  'freeze',
#  'and',
#  'crystallize\nand',
#  'be',
#  'bound',
#  'in',
#  'a',
#  'mould.\n\nFain',
#  'would',
#  'I',
#  'take',
#  'with',
#  'me',
#  'all',
#  'that',
#  'is\nhere.',
#  'But',
#  'how',
#  'shall',
#  'I?\n\nA',
#  'voice',
#  'cannot',
#  'carry',
#  'the',
#  'tongue',
#  'and\n',
#  'lips',
#  'that',
#  'gave',
#  'it',
#  'wings.',
#  'Alone\nmust',
#  'it',
#  'seek',
#  'the',
#  'ether.\n\nAnd',
#  'alone',
#  'and',
#  'without',
#  'his',
#  'nest',
#  'shall',
#  'the\neagle',
#  'fly',
#  'across',
#  'the',
#  'sun.\n\n*****\n\nNow',
#  'when',
#  'he',
#  'reached',
#  'the',
#  'foot',
#  'of',
#  'the\nhill,',
#  'he',
#  'turned',
#  'again',
#  'towards',
#  'the',
#  'sea,\nand',
#  'he',
#  'saw',
#  'his',
#  'ship',
#  'approaching',
#  'the\nharbour,',
#  'and',
#  'upon',
#  'her',
#  'prow',
#  'the',
#  'mariners,\nthe',
#  'men',
#  'of',
#  'his',
#  'own',
#  'land.\n\nAnd',
#  'his',
#  'soul',
#  'cried',
#  'out',
#  'to',
#  'them,',
#  'and',
#  'he\nsaid:\n\nSons',
#  'of',
#  'my',
#  'ancient',
#  'mother,',
#  'you',
#  'riders',
#  'of\nthe',
#  'tides,\n\nHow',
#  'often',
#  'have',
#  'you',
#  'sailed',
#  'in',
#  'my',
#  'dreams.\nAnd',
#  'now',
#  'you',
#  'come',
#  'in',
#  'my',
#  'awakening,',
#  'which\nis',
#  'my',
#  'deeper',
#  'dream.\n\nReady',
#  'am',
#  'I',
#  'to',
#  'go,',
#  'and',
#  'my',
#  'eagerness',
#  'with\nsails',
#  'full',
#  'set',
#  'awaits',
#  'the',
#  'wind.\n\nOnly',
#  'another',
#  'breath',
#  'will',
#  'I',
#  'breathe',
#  'in\nthis',
#  'still',
#  'air,',
#  'only',
#  'another',
#  'loving',
#  'look\ncast',
#  'backward,\n\nAnd',
#  'then',
#  'I',
#  'shall',
#  'stand',
#  'among',
#  'you,',
#  'a\nseafarer',
#  'among',
#  'seafarers.',
#  '',
#  'you,\nvast',
#  'sea,',
#  'sleepless',
#  'mother,\n\nWho',
#  'alone',
#  'are',
#  'peace',
#  'and',
#  'freedom',
#  'to',
#  'the\nriver',
#  'and',
#  'the',
#  'stream,\n\nOnly',
#  'another',
#  'winding',
#  'will',
#  'this',
#  'stream\nmake,',
#  'only',
#  'another',
#  'murmur',
#  'in',
#  'this',
#  'glade,\n\nAnd',
#  'then',
#  'shall',
#  'I',
#  'come',
#  'to',
#  'you,',
#  'a\nboundless',
#  'drop',
#  'to',
#  'a',
#  'boundless',
#  'ocean.\n\n*****\n\nAnd',
#  'as',
#  'he',
#  'walked',
#  'he',
#  'saw',
#  'from',
#  'afar',
#  'men\nand',
#  'women',
#  'leaving',
#  'their',
#  'fields',
#  'and',
#  'their\nvineyards',
#  'and',
#  'hastening',
#  'towards',
#  'the',
#  'city\ngates.\n\nAnd',
#  'he',
#  'heard',
#  'their',
#  'voices',
#  'calling',
#  'his\nname,',
#  'and',
#  'shouting',
#  'from',
#  'field',
#  'to',
#  'field\ntelling',
#  'one',
#  'another',
#  'of',
#  'the',
#  'coming',
#  'of',
#  'his\nship.\n\nAnd',
#  'he',
#  'said',
#  'to',
#  'himself:\n\nShall',
#  'the',
#  'day',
#  'of',
#  'parting',
#  'be',
#  'the',
#  'day',
#  'of\ngathering?\n\nAnd',
#  'shall',
#  'it',
#  'be',
#  'said',
#  'that',
#  'my',
#  'eve',
#  'was',
#  'in\ntruth',
#  'my',
#  'dawn?\n\nAnd',
#  'what',
#  'shall',
#  'I',
#  'give',
#  'unto',
#  'him',
#  'who',
#  'has\nleft',
#  'his',
#  'plough',
#  'in',
#  'midfurrow,',
#  'or',
#  'to\nhim',
#  'who',
#  'has',
#  'stopped',
#  'the',
#  'wheel',
#  'of',
#  'his\nwinepress?',
#  '',
#  'my',
#  'heart',
#  'become',
#  'a\ntree',
#  'heavy-laden',
#  'with',
#  'fruit',
#  'that',
#  'I',
#  'may\ngather',
#  'and',
#  'give',
#  'unto',
#  'them?\n\nAnd',
#  'shall',
#  'my',
#  'desires',
#  'flow',
#  'like',
#  'a\nfountain',
#  'that',
#  'I',
#  'may',
#  'fill',
#  'their',
#  'cups?\n\nAm',
#  'I',
#  'a',
#  'harp',
#  'that',
#  'the',
#  'hand',
#  'of',
#  'the',
#  'mighty\nmay',
#  'touch',
#  'me,',
#  'or',
#  'a',
#  'flute',
#  'that',
#  'his',
#  'breath\nmay',
#  'pass',
#  'through',
#  'me?\n\nA',
#  'seeker',
#  'of',
#  'silences',
#  'am',
#  'I,',
#  'and',
#  'what\ntreasure',
#  'have',
#  'I',
#  'found',
#  'in',
#  'silences',
#  'that',
#  'I\nmay',
#  'dispense',
#  'with',
#  'confidence?\n\nIf',
#  'this',
#  'is',
#  'my',
#  'day',
#  'of',
#  'harvest,',
#  'in',
#  'what\nfields',
#  'have',
#  'I',
#  'sowed',
#  'the',
#  'seed,',
#  'and',
#  'in\nwhat',
#  'unremembered',
#  'seasons?\n\nIf',
#  'this',
#  'indeed',
#  'be',
#  'the',
#  'hour',
#  'in',
#  'which',
#  'I\nlift',
#  'up',
#  'my',
#  'lantern,',
#  'it',
#  'is',
#  'not',
#  'my',
#  'flame\nthat',
#  'shall',
#  'burn',
#  'therein.\n\nEmpty',
#  'and',
#  'dark',
#  'shall',
#  'I',
#  'raise',
#  'my',
#  'lantern,\n\nAnd',
#  'the',
#  'guardian',
#  'of',
#  'the',
#  'night',
#  'shall',
#  'fill\nit',
#  'with',
#  'oil',
#  'and',
#  'he',
#  'shall',
#  'light',
#  'it',
#  'also.\n\n*****\n\nThese',
#  'things',
#  'he',
#  'said',
#  'in',
#  'words.',
#  'But',
#  'much\nin',
#  'his',
#  'heart',
#  'remained',
#  'unsaid.',
#  'For',
#  '',
#  'could',
#  'not',
#  'speak',
#  'his',
#  'deeper\nsecret.\n\n*****\n\n[Illustration:',
#  '0020]\n\nAnd',
#  'when',
#  'he',
#  'entered',
#  'into',
#  'the',
#  'city',
#  'all\nthe',
#  'people',
#  'came',
#  'to',
#  'meet',
#  'him,',
#  'and',
#  'they\nwere',
#  'crying',
#  'out',
#  'to',
#  'him',
#  'as',
#  'with',
#  'one\nvoice.\n\nAnd',
#  'the',
#  'elders',
#  'of',
#  'the',
#  'city',
#  'stood',
#  'forth\nand',
#  'said:\n\nGo',
#  'not',
#  'yet',
#  'away',
#  'from',
#  'us.\n\nA',
#  'noontide',
#  'have',
#  'you',
#  'been',
#  'in',
#  'our\ntwilight,',
#  'and',
#  'your',
#  'youth',
#  'has',
#  'given',
#  'us\ndreams',
#  'to',
#  'dream.\n\nNo',
#  'stranger',
#  'are',
#  'you',
#  'among',
#  'us,',
#  'nor\na',
#  'guest,',
#  'but',
#  'our',
#  'son',
#  'and',
#  'our',
#  'dearly\nbeloved.\n\nSuffer',
#  'not',
#  'yet',
#  'our',
#  'eyes',
#  'to',
#  'hunger',
#  'for\nyour',
#  'face.\n\n*****\n\nAnd',
#  'the',
#  'priests',
#  'and',
#  'the',
#  'priestesses',
#  'said\nunto',
#  'him:\n\nLet',
#  'not',
#  'the',
#  'waves',
#  'of',
#  'the',
#  'sea',
#  'separate',
#  'us\nnow,',
#  'and',
#  'the',
#  'years',
#  'you',
#  'have',
#  'spent',
#  'in',
#  'our\nmidst',
#  'become',
#  'a',
#  'memory.\n\nYou',
#  'have',
#  'walked',
#  'among',
#  'us',
#  'a',
#  'spirit,\n',
#  'your',
#  'shadow',
#  'has',
#  'been',
#  'a',
#  'light\nupon',
#  'our',
#  'faces.\n\nMuch',
#  'have',
#  'we',
#  'loved',
#  'you.',
#  'But',
#  'speechless\nwas',
#  'our',
#  'love,',
#  'and',
#  'with',
#  'veils',
#  'has',
#  'it',
#  'been\nveiled.\n\nYet',
#  'now',
#  'it',
#  'cries',
#  'aloud',
#  'unto',
#  'you,',
#  'and\nwould',
#  'stand',
#  'revealed',
#  'before',
#  'you.\n\nAnd',
#  'ever',
#  'has',
#  'it',
#  'been',
#  'that',
#  'love',
#  'knows\nnot',
#  'its',
#  'own',
#  'depth',
#  'until',
#  'the',
#  'hour',
#  'of\nseparation.\n\n*****\n\nAnd',
#  'others',
#  'came',
#  'also',
#  'and',
#  'entreated',
#  'him.\nBut',
#  'he',
#  'answered',
#  'them',
#  'not.',
#  'He',
#  'only',
#  'bent\nhis',
#  'head;',
#  'and',
#  'those',
#  'who',
#  'stood',
#  'near',
#  'saw\nhis',
#  'tears',
#  'falling',
#  'upon',
#  'his',
#  'breast.\n\nAnd',
#  'he',
#  'and',
#  'the',
#  'people',
#  'proceeded',
#  'towards\nthe',
#  'great',
#  'square',
#  'before',
#  'the',
#  'temple.\n\nAnd',
#  'there',
#  'came',
#  'out',
#  'of',
#  'the',
#  'sanctuary',
#  'a\nwoman',
#  'whose',
#  'name',
#  'was',
#  'Almitra.',
#  'And',
#  'she\nwas',
#  'a',
#  'seeress.\n\nAnd',
#  'he',
#  'looked',
#  'upon',
#  'her',
#  'with',
#  'exceeding\ntenderness,',
#  'for',
#  'it',
#  'was',
#  'she',
#  'who',
#  'had',
#  'first\nsought',
#  'and',
#  'believed',
#  'in',
#  'him',
#  'when',
#  'he',
#  'had\nbeen',
#  'but',
#  'a',
#  'day',
#  'in',
#  'their',
#  'city.',
#  '',
#  'hailed',
#  'him,',
#  'saying:\n\nProphet',
#  'of',
#  'God,',
#  'in',
#  'quest',
#  'of',
#  'the\nuttermost,',
#  'long',
#  'have',
#  'you',
#  'searched',
#  'the\ndistances',
#  'for',
#  'your',
#  'ship.\n\nAnd',
#  'now',
#  'your',
#  'ship',
#  'has',
#  'come,',
#  'and',
#  'you',
#  'must\nneeds',
#  'go.\n\nDeep',
#  'is',
#  'your',
#  'longing',
#  'for',
#  'the',
#  'land',
#  'of\nyour',
#  'memories',
#  'and',
#  'the',
#  'dwelling',
#  'place\nof',
#  'your',
#  'greater',
#  'desires;',
#  'and',
#  'our',
#  'love\nwould',
#  'not',
#  'bind',
#  'you',
#  'nor',
#  'our',
#  'needs',
#  'hold\nyou.\n\nYet',
#  'this',
#  'we',
#  'ask',
#  'ere',
#  'you',
#  'leave',
#  'us,',
#  'that\nyou',
#  'speak',
#  'to',
#  'us',
#  'and',
#  'give',
#  'us',
#  'of',
#  'your\ntruth.\n\nAnd',
#  'we',
#  'will',
#  'give',
#  'it',
#  'unto',
#  'our',
#  'children,\nand',
#  'they',
#  'unto',
#  'their',
#  'children,',
#  'and',
#  'it\nshall',
#  'not',
#  'perish.\n\nIn',
#  'your',
#  'aloneness',
#  'you',
#  'have',
#  'watched',
#  'with\nour',
#  'days,',
#  'and',
#  'in',
#  'your',
#  'wakefulness',
#  'you\nhave',
#  'listened',
#  'to',
#  'the',
#  'weeping',
#  'and',
#  'the\nlaughter',
#  'of',
#  'our',
#  'sleep.\n\nNow',
#  'therefore',
#  'disclose',
#  'us',
#  'to',
#  'ourselves,\nand',
#  'tell',
#  'us',
#  'all',
#  'that',
#  'has',
#  'been',
#  'shown\nyou',
#  'of',
#  'that',
#  'which',
#  'is',
#  'between',
#  'birth',
#  'and\ndeath.\n\n*****\n\nAnd',
#  'he',
#  'answered,\n\nPeople',
#  'of',
#  ...]

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']
    '''
    
    # Your code here:
    flatten = lambda x: [item for sublist in x for item in sublist]
    return (flatten, x)

prophet_line = list(map(line_break, prophet_reference))
prophet_line
# Out:
# [(<function __main__.line_break.<locals>.<lambda>(x)>,
#   'Farewell................92\n\n\n\n\nTHE'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>,
#   'PROPHET\n\n|Almustafa,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'chosen'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the\nbeloved,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'who'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'was'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'dawn'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'unto'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'own\nday,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'had'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'waited'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'twelve'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'years'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'city\nof'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'Orphalese'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'for'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'ship'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'was'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to\nreturn'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'bear'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'him'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'back'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'isle'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of\nhis'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'birth.\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'twelfth'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'year,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'on'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'seventh\nday'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'Ielool,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'month'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'reaping,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he\nclimbed'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'hill'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'without'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'city'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'walls\nand'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'looked'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'seaward;'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'beheld'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his\nship'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'coming'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'with'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'mist.\n\nThen'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'gates'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'heart'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'were'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'flung\nopen,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'joy'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'flew'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'far'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'over'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'sea.\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'closed'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'eyes'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'prayed'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the\nsilences'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>,
#   'soul.\n\n*****\n\nBut'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'as'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'descended'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'hill,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'sadness\ncame'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'upon'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'him,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'thought'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his\nheart:\n\nHow'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'go'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'peace'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'without\nsorrow?'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'Nay,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'not'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'without'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'wound'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the\nspirit'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'leave'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'this'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'city.'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, ''),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'days'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'pain'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'have'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'spent\nwithin'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'its'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'walls,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'long'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'were'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the\nnights'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'aloneness;'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'who'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'can'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'depart\nfrom'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'pain'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'aloneness'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>,
#   'without\nregret?\n\nToo'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'many'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'fragments'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'spirit'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'have'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I\nscattered'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'these'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'streets,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'too'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'many\nare'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'children'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'longing'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'walk\nnaked'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'among'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'these'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'hills,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'cannot\nwithdraw'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'from'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'them'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'without'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'burden'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and\nan'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'ache.\n\nIt'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'is'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'not'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'garment'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'cast'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'off'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'this\nday,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'but'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'skin'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'tear'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'with'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'own\nhands.\n\nNor'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'is'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'it'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'thought'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'leave'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'behind'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'me,\nbut'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'heart'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'made'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'sweet'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'with'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'hunger'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and\nwith'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>,
#   'thirst.\n\n*****\n\nYet'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'cannot'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'tarry'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'longer.\n\nThe'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'sea'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'calls'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'all'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'things'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'unto'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'her\ncalls'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'me,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'must'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'embark.\n\nFor'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'stay,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'though'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'hours'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'burn'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in\nthe'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'night,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'is'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'freeze'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'crystallize\nand'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'be'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'bound'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'mould.\n\nFain'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'would'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'take'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'with'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'me'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'all'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'is\nhere.'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'But'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'how'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I?\n\nA'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'voice'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'cannot'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'carry'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'tongue'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and\n'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'lips'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'gave'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'it'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'wings.'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'Alone\nmust'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'it'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'seek'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'ether.\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'alone'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'without'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'nest'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the\neagle'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'fly'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'across'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'sun.\n\n*****\n\nNow'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'when'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'reached'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'foot'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the\nhill,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'turned'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'again'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'towards'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'sea,\nand'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'saw'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'ship'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'approaching'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the\nharbour,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'upon'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'her'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'prow'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'mariners,\nthe'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'men'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'own'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'land.\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'soul'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'cried'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'out'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'them,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he\nsaid:\n\nSons'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'ancient'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'mother,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'riders'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of\nthe'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'tides,\n\nHow'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'often'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'have'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'sailed'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'dreams.\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'now'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'come'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'awakening,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'which\nis'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'deeper'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'dream.\n\nReady'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'am'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'go,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'eagerness'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'with\nsails'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'full'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'set'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'awaits'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'wind.\n\nOnly'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'another'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'breath'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'will'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'breathe'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in\nthis'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'still'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'air,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'only'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'another'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'loving'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'look\ncast'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'backward,\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'then'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'stand'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'among'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a\nseafarer'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'among'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'seafarers.'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, ''),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you,\nvast'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'sea,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'sleepless'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'mother,\n\nWho'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'alone'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'are'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'peace'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'freedom'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the\nriver'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'stream,\n\nOnly'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'another'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'winding'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'will'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'this'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'stream\nmake,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'only'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'another'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'murmur'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'this'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'glade,\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'then'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'come'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a\nboundless'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'drop'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'boundless'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>,
#   'ocean.\n\n*****\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'as'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'walked'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'saw'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'from'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'afar'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'men\nand'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'women'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'leaving'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'their'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'fields'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'their\nvineyards'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'hastening'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'towards'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'city\ngates.\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'heard'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'their'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'voices'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'calling'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his\nname,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shouting'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'from'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'field'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'field\ntelling'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'one'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'another'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'coming'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his\nship.\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'said'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'himself:\n\nShall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'day'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'parting'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'be'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'day'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>,
#   'of\ngathering?\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'it'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'be'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'said'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'eve'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'was'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in\ntruth'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'dawn?\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'what'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'give'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'unto'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'him'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'who'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'has\nleft'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'plough'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'midfurrow,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'or'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to\nhim'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'who'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'has'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'stopped'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'wheel'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his\nwinepress?'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, ''),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'heart'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'become'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a\ntree'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'heavy-laden'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'with'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'fruit'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'may\ngather'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'give'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'unto'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'them?\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'desires'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'flow'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'like'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a\nfountain'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'may'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'fill'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'their'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'cups?\n\nAm'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'harp'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'hand'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'mighty\nmay'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'touch'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'me,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'or'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'flute'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'breath\nmay'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'pass'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'through'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'me?\n\nA'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'seeker'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'silences'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'am'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'what\ntreasure'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'have'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'found'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'silences'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I\nmay'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'dispense'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'with'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'confidence?\n\nIf'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'this'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'is'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'day'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'harvest,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'what\nfields'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'have'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'sowed'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'seed,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in\nwhat'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'unremembered'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'seasons?\n\nIf'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'this'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'indeed'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'be'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'hour'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'which'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I\nlift'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'up'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'lantern,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'it'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'is'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'not'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'flame\nthat'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'burn'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'therein.\n\nEmpty'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'dark'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'I'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'raise'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'my'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'lantern,\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'guardian'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'night'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'fill\nit'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'with'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'oil'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'light'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'it'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>,
#   'also.\n\n*****\n\nThese'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'things'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'said'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'words.'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'But'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'much\nin'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'heart'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'remained'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'unsaid.'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'For'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, ''),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'could'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'not'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'speak'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>,
#   'deeper\nsecret.\n\n*****\n\n[Illustration:'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, '0020]\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'when'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'entered'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'into'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'city'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'all\nthe'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'people'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'came'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'meet'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'him,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'they\nwere'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'crying'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'out'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'him'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'as'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'with'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'one\nvoice.\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'elders'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'city'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'stood'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'forth\nand'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'said:\n\nGo'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'not'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'yet'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'away'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'from'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'us.\n\nA'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'noontide'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'have'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'been'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'our\ntwilight,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'your'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'youth'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'has'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'given'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'us\ndreams'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'dream.\n\nNo'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'stranger'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'are'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'among'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'us,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'nor\na'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'guest,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'but'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'our'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'son'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'our'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>,
#   'dearly\nbeloved.\n\nSuffer'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'not'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'yet'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'our'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'eyes'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'hunger'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'for\nyour'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>,
#   'face.\n\n*****\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'priests'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'priestesses'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'said\nunto'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'him:\n\nLet'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'not'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'waves'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'sea'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'separate'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'us\nnow,'),
# ...
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'faces.\n\nMuch'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'have'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'we'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'loved'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you.'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'But'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'speechless\nwas'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'our'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'love,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'with'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'veils'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'has'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'it'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'been\nveiled.\n\nYet'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'now'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'it'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'cries'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'aloud'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'unto'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and\nwould'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'stand'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'revealed'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'before'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you.\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'ever'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'has'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'it'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'been'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'love'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'knows\nnot'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'its'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'own'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'depth'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'until'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'hour'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>,
#   'of\nseparation.\n\n*****\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'others'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'came'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'also'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'entreated'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'him.\nBut'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'answered'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'them'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'not.'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'He'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'only'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'bent\nhis'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'head;'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'those'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'who'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'stood'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'near'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'saw\nhis'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'tears'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'falling'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'upon'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'his'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'breast.\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'people'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'proceeded'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'towards\nthe'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'great'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'square'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'before'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'temple.\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'there'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'came'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'out'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'sanctuary'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a\nwoman'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'whose'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'name'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'was'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'Almitra.'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'And'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'she\nwas'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'seeress.\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'looked'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'upon'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'her'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'with'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>,
#   'exceeding\ntenderness,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'for'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'it'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'was'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'she'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'who'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'had'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'first\nsought'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'believed'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'him'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'when'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'had\nbeen'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'but'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'a'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'day'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'their'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'city.'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, ''),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'hailed'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'him,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'saying:\n\nProphet'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'God,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'quest'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the\nuttermost,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'long'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'have'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'searched'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the\ndistances'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'for'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'your'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'ship.\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'now'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'your'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'ship'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'has'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'come,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'must\nneeds'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'go.\n\nDeep'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'is'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'your'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'longing'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'for'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'land'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of\nyour'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'memories'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'dwelling'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'place\nof'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'your'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'greater'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'desires;'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'our'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'love\nwould'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'not'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'bind'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'nor'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'our'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'needs'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'hold\nyou.\n\nYet'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'this'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'we'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'ask'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'ere'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'leave'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'us,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that\nyou'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'speak'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'us'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'give'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'us'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'your\ntruth.\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'we'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'will'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'give'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'it'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'unto'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'our'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'children,\nand'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'they'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'unto'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'their'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'children,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'it\nshall'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'not'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'perish.\n\nIn'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'your'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'aloneness'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'have'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'watched'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'with\nour'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'days,'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'in'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'your'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'wakefulness'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'you\nhave'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'listened'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'weeping'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'and'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'the\nlaughter'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'our'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'sleep.\n\nNow'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'therefore'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'disclose'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'us'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'to'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'ourselves,\nand'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'tell'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'us'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'all'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'has'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'been'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'shown\nyou'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'that'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'which'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'is'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'between'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'birth'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>,
#   'and\ndeath.\n\n*****\n\nAnd'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'he'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'answered,\n\nPeople'),
#  (<function __main__.line_break.<locals>.<lambda>(x)>, 'of'),
#  ...]

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
# Your code here:

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
# Your code here:

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: true if the word is not in the specified list and false if the word is in the list
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    
    word_list = ['and', 'the', 'a', 'an']
    
    # Your code here:

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %% [markdown]
# # Bonus Challenge - Part 1
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an']
    
    # Your code here:

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    
    # Your code here:

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
# Your code here:

# %% [markdown]
# # Challenge 4 - Applying Functions to DataFrames
#
# #### Our next step is to use the apply function to a dataframe and transform all cells.
#
# To do this, we will load a dataset below and then write a function that will perform the transformation.

# %%
# Run this code:

# The dataset below contains information about pollution from PM2.5 particles in Beijing 

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00381/PRSA_data_2010.1.1-2014.12.31.csv"
pm25 = pd.read_csv(url)

# %% [markdown]
# Let's look at the data using the `head()` function.

# %%
# Your code here:

# %% [markdown]
# The next step is to create a function that divides a cell by 24 to produce an hourly figure. Write the function below.

# %%
def hourly(x):
    '''
    Input: A numerical value
    Output: The value divided by 24
        
    Example:
    Input: 48
    Output: 2.0
    '''
    
    # Your code here:

# %% [markdown]
# Apply this function to the columns `Iws`, `Is`, and `Ir`. Store this new dataframe in the variable `pm25_hourly`.

# %%
# Your code here:

# %% [markdown]
# #### Our last challenge will be to create an aggregate function and apply it to a select group of columns in our dataframe.
#
# Write a function that returns the standard deviation of a column divided by the length of a column minus 1. Since we are using pandas, do not use the `len()` function. One alternative is to use `count()`. Also, use the numpy version of standard deviation.

# %%
def sample_sd(x):
    '''
    Input: A Pandas series of values
    Output: the standard deviation divided by the number of elements in the series
        
    Example:
    Input: pd.Series([1,2,3,4])
    Output: 0.3726779962
    '''
    
    # Your code here:
